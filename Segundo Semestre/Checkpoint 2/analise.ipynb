# %%
import pandas as pd

df = pd.read_csv("precipitacao.csv")

df.head()
# Out:
#          X        Y  OBJECTID    ID       CD    CDALT                NM  \
# 0 -47.8167 -20.3500      4545  4670  2047012   B4-006  ITUVERAVA - ACCO
# 1 -47.3500 -20.3500      4546  4671  2047013   B4-055     VALE DO PRATA
# 2 -47.8333 -20.5167      4547  4672  2047015  B4-047R  PIONEIROS (CMEF)
# 3 -47.4233 -20.5442      4548  4673  2047016      ANA            FRANCA
# 4 -47.4000 -20.5167      4549  4674  2047017   B4-001            FRANCA
#
#      RIO   RESPON   OPERAD  ... MESMAX MESMIN  BIMMAX  BIMMIN    TRIMAX  \
# 0 -99999  DAEE-SP  DAEE-SP  ...      1      8   01_02   07_08  12_01_02
# 1 -99999  DAEE-SP  DAEE-SP  ...      1      7   12_01   06_07  12_01_02
# 2 -99999  DAEE-SP  DAEE-SP  ...      1      8   12_01   07_08  12_01_02
# 3 -99999      ANA     CPRM  ...     12      7   12_01   07_08  12_01_02
# 4 -99999  DAEE-SP  DAEE-SP  ...      1      7   12_01   07_08  12_01_02
#
#      TRIMIN       QUAMAX       QUAMIN             SEMMAX             SEMMIN
# ...

# %%
regioes_unicas = df["NM"].unique()

regioes_unicas

# %%
# Ribeirao Preto -> muito alagamento
